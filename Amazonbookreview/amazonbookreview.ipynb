# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("Amazonbookreviews.csv")

# a. Creating subsets of the dataset row-wise
subset1 = df.iloc[:20]  # First 20 rows
subset2 = df.iloc[20:]  # Remaining rows

# b. Merging datasets row-wise
merged_rows = pd.concat([subset1, subset2], axis=0)

# c. Sorting data by overallRating descending
sorted_df = df.sort_values(by='overallRating', ascending=False)

# d. Transposing data (only first 5 rows for readability)
transposed_df = df.head().transpose()

# e. Reshaping data: count of reviews per reviewer
reshaped_df = df.pivot_table(index='reviewername', values='overallRating', aggfunc='count')

# f. Creating subsets of the dataset column-wise
col_subset = df[['reviewerID', 'reviewername', 'overallRating']]

# g. Merging datasets column-wise
col_part1 = df.iloc[:, :4]   # First 4 columns
col_part2 = df.iloc[:, 4:]   # Remaining columns
merged_cols = pd.concat([col_part1, col_part2], axis=1)

# Display example outputs
print("Row Subset 1:\n", subset1.head(), "\n")
print("Row Subset 2:\n", subset2.head(), "\n")
print("Merged Rows:\n", merged_rows.head(), "\n")
print("Sorted by Rating:\n", sorted_df.head(), "\n")
print("Transposed (first 5 rows):\n", transposed_df, "\n")
print("Reshaped (count of reviews per reviewer):\n", reshaped_df, "\n")
print("Column Subset:\n", col_subset.head(), "\n")
print("Merged Columns:\n", merged_cols.head(), "\n")
# Out:
# Row Subset 1:
#         reviewerID      asin reviewername  helpful  \
# 0  A2SUAM1J3GNN3B   23456.0        SNEHA        2
# 1  A2SUAN1J3GNN0C  879877.0      KARTHII        3
# 2  A2SUAN1J3GNN7B   23456.0     SHASHANK        3
# 3  A5SUAN1J3GNN9B   67578.0        NITIN        3
# 4  A1SUAM1J3GNN3B     123.0      PRANOTI        3
#
#                                         reviewerText  overallRating  \
# 0  I bought this for my husband who plays the pia...            4.0
# 1                                  good book to read            3.0
# 2                                          high cost            2.5
# 3                                    good useof book            2.2
# 4                            I m happy with the book            3.0
#
#             Summary  UnixreviewTime  reviewTime
# 0       SUBWAY SURF             NaN         NaN
# 1            PILOT              NaN         NaN
# 2   DRIVE IN HEAVEN             NaN         NaN
# 3     SPORTS HEAVEN             NaN         NaN
# 4  HEAVEN OF PEARLS             NaN         NaN
#
# Row Subset 2:
#          reviewerID    asin reviewername  helpful reviewerText  overallRating  \
# 20   VABI9876ERTT1  9876.0       MANISH        2        fdghi            2.0
# 21  NIKI12NIKI1231  3451.0       SHREYA        2    dvdasaewb            4.0
# 22  MIKISDF1232XAD   879.0    AISHWARYA        2          NA             4.0
# 23    GHAU8768QWER   321.0       SUMEET        2          NA             4.0
# 24  NIKI12NIKI1231     2.0      PRAJWAL        3          NA             4.0
#
#                   Summary  UnixreviewTime  reviewTime
# 20           ONE FOR ALLL             NaN         NaN
# 21           DATA IS DATA             NaN         NaN
# 22  INDIA A MASSIVE POWER             NaN         NaN
# 23           FRIENDS HELP             NaN         NaN
# 24           MOTIVATIONAL             NaN         NaN
#
# Merged Rows:
#         reviewerID      asin reviewername  helpful  \
# 0  A2SUAM1J3GNN3B   23456.0        SNEHA        2
# 1  A2SUAN1J3GNN0C  879877.0      KARTHII        3
# 2  A2SUAN1J3GNN7B   23456.0     SHASHANK        3
# 3  A5SUAN1J3GNN9B   67578.0        NITIN        3
# 4  A1SUAM1J3GNN3B     123.0      PRANOTI        3
#
#                                         reviewerText  overallRating  \
# 0  I bought this for my husband who plays the pia...            4.0
# 1                                  good book to read            3.0
# 2                                          high cost            2.5
# 3                                    good useof book            2.2
# 4                            I m happy with the book            3.0
#
#             Summary  UnixreviewTime  reviewTime
# 0       SUBWAY SURF             NaN         NaN
# 1            PILOT              NaN         NaN
# 2   DRIVE IN HEAVEN             NaN         NaN
# 3     SPORTS HEAVEN             NaN         NaN
# 4  HEAVEN OF PEARLS             NaN         NaN
#
# Sorted by Rating:
#          reviewerID     asin reviewername  helpful  \
# 9   1234ZSDFREQWEG  78761.0       SATISH        2
# 0   A2SUAM1J3GNN3B  23456.0        SNEHA        2
# 21  NIKI12NIKI1231   3451.0       SHREYA        2
# 43     123LKIUHNFG   9800.0         MAHI        2
# 42      QWCVFED123  11111.0        DHONI        2
#
#                                          reviewerText  overallRating  \
# 9                                         many errors            5.0
# 0   I bought this for my husband who plays the pia...            4.0
# 21                                          dvdasaewb            4.0
# 43                              DAER PLEASE READ BOOK            4.0
# 42                                         HELLO DEAR            4.0
#
#          Summary  UnixreviewTime  reviewTime
# 9   DATA IS DATA             NaN         NaN
# 0    SUBWAY SURF             NaN         NaN
# 21  DATA IS DATA             NaN         NaN
# 43       MOTHER              NaN         NaN
# 42   DEAR TO ALL             NaN         NaN
#
# Transposed (first 5 rows):
#                                                                  0  \
# reviewerID                                         A2SUAM1J3GNN3B
# asin                                                      23456.0
# reviewername                                                SNEHA
# helpful                                                         2
# reviewerText    I bought this for my husband who plays the pia...
# overallRating                                                 4.0
# Summary                                               SUBWAY SURF
# UnixreviewTime                                                NaN
# reviewTime                                                    NaN
#
#                                 1                2                3  \
# reviewerID         A2SUAN1J3GNN0C   A2SUAN1J3GNN7B   A5SUAN1J3GNN9B
# asin                     879877.0          23456.0          67578.0
# reviewername              KARTHII         SHASHANK            NITIN
# helpful                         3                3                3
# reviewerText    good book to read        high cost  good useof book
# overallRating                 3.0              2.5              2.2
# Summary                    PILOT   DRIVE IN HEAVEN    SPORTS HEAVEN
# UnixreviewTime                NaN              NaN              NaN
# reviewTime                    NaN              NaN              NaN
#
#                                       4
# reviewerID               A1SUAM1J3GNN3B
# asin                              123.0
# reviewername                    PRANOTI
# helpful                               3
# reviewerText    I m happy with the book
# overallRating                       3.0
# Summary                HEAVEN OF PEARLS
# UnixreviewTime                      NaN
# reviewTime                          NaN
#
# Reshaped (count of reviews per reviewer):
#                overallRating
# reviewername
# AISHWARYA                 1
# AKSHAY                    1
# CHRIS                     1
# DDE                       1
# DHONI                     1
# DIPTI                     1
# HARRY                     1
# JACOB                     1
# JOHN                      1
# KAILASH                   1
# KANGANA                   1
# KARTHII                   1
# KHANN                     1
# KRISSH                    1
# MAHI                      1
# MANISH                    1
# MARYLS                    1
# MOHIT                     1
# MORRIS                    1
# NANAJJI                   1
# NEIL                      1
# NILESH                    1
# NITIN                     1
# PANKAJ                    1
# PRAJWAL                   1
# PRANOTI                   1
# PREETI                    1
# RAJESH                    1
# RAJU                      1
# RIYAA                     1
# ROHIT                     1
# SAIF                      1
# SALMAN                    1
# SATISH                    1
# SHALINI                   1
# SHASHANK                  1
# SHIKHA                    1
# SHRADDHA                  1
# SHREYA                    1
# SNEHA                     1
# SNEHAL                    1
# SONAM                     1
# SUMEET                    1
# VARSHA                    1
#
# Column Subset:
#         reviewerID reviewername  overallRating
# 0  A2SUAM1J3GNN3B        SNEHA            4.0
# 1  A2SUAN1J3GNN0C      KARTHII            3.0
# 2  A2SUAN1J3GNN7B     SHASHANK            2.5
# 3  A5SUAN1J3GNN9B        NITIN            2.2
# 4  A1SUAM1J3GNN3B      PRANOTI            3.0
#
# Merged Columns:
#         reviewerID      asin reviewername  helpful  \
# 0  A2SUAM1J3GNN3B   23456.0        SNEHA        2
# 1  A2SUAN1J3GNN0C  879877.0      KARTHII        3
# 2  A2SUAN1J3GNN7B   23456.0     SHASHANK        3
# 3  A5SUAN1J3GNN9B   67578.0        NITIN        3
# 4  A1SUAM1J3GNN3B     123.0      PRANOTI        3
#
#                                         reviewerText  overallRating  \
# 0  I bought this for my husband who plays the pia...            4.0
# 1                                  good book to read            3.0
# 2                                          high cost            2.5
# 3                                    good useof book            2.2
# 4                            I m happy with the book            3.0
#
#             Summary  UnixreviewTime  reviewTime
# 0       SUBWAY SURF             NaN         NaN
# 1            PILOT              NaN         NaN
# 2   DRIVE IN HEAVEN             NaN         NaN
# 3     SPORTS HEAVEN             NaN         NaN
# 4  HEAVEN OF PEARLS             NaN         NaN
